# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/compat/v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
data = keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = data.load_data()

# %%
class_name = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag',' ANkle boot']

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
input_size = 784
output_size = 10
hidden_layer_size = 128

model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28,28)),
    keras.layers.Dense(hidden_layer_size, activation='relu'), # 1st hidden layer
    keras.layers.Dense(hidden_layer_size, activation='relu'), # 2nd hidden layer
    keras.layers.Dense(hidden_layer_size, activation='relu'), # 3rd hidden layer
    keras.layers.Dense(output_size, activation= 'softmax')
])
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# determine the maximum number of epochs
NUM_EPOCHS = 5

# we fit the model, specifying the
# training data
# the total number of epochs
# and the validation data we just created ourselves in the format: (inputs,targets)
model.fit(train_images,
          train_labels,
          epochs=NUM_EPOCHS
          )
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.4840 - acc: 0.82370s - loss: 0.4860 - acc: 0.8
# Epoch 2/5
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.3641 - acc: 0.8667
# Epoch 3/5
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.3301 - acc: 0.8783
# Epoch 4/5
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3121 - acc: 0.8838
# Epoch 5/5
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.2916 - acc: 0.8904

# %%
prediction = model.predict(test_images)

# %%
pred_val = prediction[8]
pred_val
# Out:
# array([5.8889121e-08, 5.7101897e-12, 6.8857869e-10, 2.0185695e-11,
#        1.0745989e-11, 9.9997544e-01, 1.4318766e-08, 2.3947623e-05,
#        2.9287364e-09, 4.8199291e-07], dtype=float32)

# %%
np.argmax(pred_val)
# Out:
# 5

# %%
class_name[np.argmax(pred_val)]
# Out:
# 'Sandal'

# %%
for i in range(100):
    plt.grid(False)
    plt.imshow(test_images[i], cmap = plt.cm.binary)
    plt.xlabel=("Actual:" + class_name[test_labels[i]])
    plt.title=("Prediction:" + class_name[np.argmax(prediction[i])])
    plt.show()

    print("Actual:" + class_name[test_labels[i]])
    print("Prediction:" + class_name[np.argmax(prediction[i])])
# Out:
# Actual: ANkle boot
# Prediction: ANkle boot
# Actual:Pullover
# Prediction:Pullover
# Actual:Trouser
# Prediction:Trouser
# Actual:Trouser
# Prediction:Trouser
# Actual:Shirt
# Prediction:Shirt
# Actual:Trouser
# Prediction:Trouser
# Actual:Coat
# Prediction:Coat
# Actual:Shirt
# Prediction:Shirt
# Actual:Sandal
# Prediction:Sandal
# Actual:Sneaker
# Prediction:Sneaker
# Actual:Coat
# Prediction:Coat
# Actual:Sandal
# Prediction:Sandal
# Actual:Sneaker
# Prediction:Sneaker
# Actual:Dress
# Prediction:Dress
# Actual:Coat
# Prediction:Coat
# Actual:Trouser
# Prediction:Trouser
# Actual:Pullover
# Prediction:Pullover
# Actual:Coat
# Prediction:Pullover
# Actual:Bag
# Prediction:Bag
# Actual:T-shirt/top
# Prediction:T-shirt/top
# Actual:Pullover
# Prediction:Pullover
# Actual:Sandal
# Prediction:Sneaker
# Actual:Sneaker
# Prediction:Sneaker
# Actual: ANkle boot
# Prediction:Sandal
# Actual:Trouser
# Prediction:Trouser
# Actual:Coat
# Prediction:Pullover
# Actual:Shirt
# Prediction:Shirt
# Actual:T-shirt/top
# Prediction:T-shirt/top
# Actual: ANkle boot
# Prediction: ANkle boot
# Actual:Dress
# Prediction:Dress
# Actual:Bag
# Prediction:Bag
# Actual:Bag
# Prediction:Bag
# Actual:Dress
# Prediction:Dress
# Actual:Dress
# Prediction:Dress
# Actual:Bag
# Prediction:Bag
# Actual:T-shirt/top
# Prediction:T-shirt/top
# Actual:Sneaker
# Prediction:Sneaker
# Actual:Sandal
# Prediction:Sandal
# Actual:Sneaker
# Prediction:Sneaker
# Actual: ANkle boot
# Prediction: ANkle boot
# Actual:Shirt
# Prediction:T-shirt/top
# Actual:Trouser
# Prediction:Trouser
# Actual:Dress
# Prediction:Shirt
# Actual:Sneaker
# Prediction:Sneaker
# Actual:Shirt
# Prediction:Shirt
# Actual:Sneaker
# Prediction:Sneaker
# Actual:Pullover
# Prediction:Pullover
# Actual:Trouser
# Prediction:Trouser
# Actual:Pullover
# Prediction:Pullover
# Actual:Pullover
# Prediction:Shirt
# Actual:Coat
# Prediction:Coat
# Actual:Coat
# Prediction:Pullover
# Actual:Sandal
# Prediction:Sandal
# Actual:Bag
# Prediction:Bag
# Actual:Pullover
# Prediction:Pullover
# Actual:Pullover
# Prediction:Pullover
# Actual:Bag
# Prediction:Bag
# Actual:Coat
# Prediction:Coat
# Actual:Bag
# Prediction:Bag
# Actual:T-shirt/top
# Prediction:T-shirt/top
# Actual:Sneaker
# Prediction:Sneaker
# Actual:Sneaker
# Prediction:Sneaker
# Actual:Bag
# Prediction:Bag
# Actual:Sandal
# Prediction:Sandal
# Actual:Trouser
# Prediction:Trouser
# Actual:Trouser
# Prediction:Trouser
# Actual:Pullover
# Prediction:Dress
# Actual:Dress
# Prediction:Dress
# Actual: ANkle boot
# Prediction:Sneaker
# Actual:Bag
# Prediction:Bag
# Actual:Sneaker
# Prediction:Sneaker
# Actual:T-shirt/top
# Prediction:T-shirt/top
# Actual:Pullover
# Prediction:Pullover
# Actual:Shirt
# Prediction:Shirt
# Actual:Pullover
# Prediction:Pullover
# Actual:Dress
# Prediction:Dress
# Actual:Trouser
# Prediction:Trouser
# Actual:Pullover
# Prediction:Pullover
# Actual:Bag
# Prediction:Bag
# Actual:Coat
# Prediction:Coat
# Actual:Trouser
# Prediction:Trouser
# Actual:Bag
# Prediction:Bag
# Actual:Sandal
# Prediction:Sandal
# Actual: ANkle boot
# Prediction: ANkle boot
# Actual:Sandal
# Prediction:Sandal
# Actual:T-shirt/top
# Prediction:T-shirt/top
# Actual:Dress
# Prediction:Dress
# Actual:Pullover
# Prediction:Pullover
# Actual:T-shirt/top
# Prediction:T-shirt/top
# Actual:Shirt
# Prediction:Pullover
# Actual:Sandal
# Prediction:Sandal
# Actual:Dress
# Prediction:Dress
# Actual:Shirt
# Prediction:Shirt
# Actual:Sneaker
# Prediction:Sneaker
# Actual:Trouser
# Prediction:Trouser
# Actual:Bag
# Prediction:Bag
# Actual:T-shirt/top
# Prediction:T-shirt/top
# Actual:Trouser
# Prediction:Trouser
# Actual:Coat
# Prediction:Pullover
# Actual:Pullover
# Prediction:Pullover

# %%
#test_loss, test_accuracy = model.evaluate(test_data)

test_loss, test_accuracy = model.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 0s 48us/sample - loss: 0.3741 - acc: 0.8652

# %%
print('Test loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# Test loss: 0.37. Test accuracy: 86.52%
