# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
from sklearn import preprocessing

# %% [markdown]
# # Importing the data

# %%
raw_csv = np.loadtxt('Audiobooks_data.csv', delimiter = ',')
type(raw_csv)
# Out:
# numpy.ndarray

# %%
raw_csv.shape
# Out:
# (14084, 12)

# %%
unscaled_inputs_all = raw_csv[:,1:-1]
unscaled_inputs_all.shape
# Out:
# (14084, 10)

# %%
targets_all = raw_csv[:,-1]
targets_all
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %% [markdown]
# # Shuffle the data

# %%
shuffled_indices = np.arange(unscaled_inputs_all.shape[0])
#print(shuffled_indices)
np.random.shuffle(shuffled_indices)
#print(shuffled_indices)

# Use the shuffled indices to shuffle the inputs and targets.
unscaled_inputs_all = unscaled_inputs_all[shuffled_indices]
targets_all = targets_all[shuffled_indices]

# %% [markdown]
# # Balance the dataset

# %%
onesCount = int(np.sum(targets_all))
onesCount
# Out:
# 2237

# %%
zero_targets_counter = 0 
indices_to_remove = []
for i in range(targets_all.shape[0]):
    if int(targets_all[i]) == 0:
        zero_targets_counter += 1
        if zero_targets_counter > onesCount:
            indices_to_remove.append(i)

# %%
# Create two new variables, one that will contain the inputs, and one that will contain the targets.
# We delete all indices that we marked "to remove" in the loop above.
unscaled_inputs_equal_priors = np.delete(unscaled_inputs_all, indices_to_remove, axis=0)
unscaled_inputs_equal_priors.shape
# Out:
# (4474, 10)

# %%
targets_equal_priors = np.delete(targets_all, indices_to_remove, axis=0)
targets_equal_priors.shape
# Out:
# (4474,)

# %% [markdown]
# # Standardize the inputs

# %%
scaled_inputs = preprocessing.scale(unscaled_inputs_equal_priors)
scaled_inputs.shape
# Out:
# (4474, 10)

# %% [markdown]
# # Shuffle the scaled data

# %%
shuffled_indices = np.arange(scaled_inputs.shape[0])
np.random.shuffle(shuffled_indices)
shuffled_inputs = scaled_inputs[shuffled_indices]
shuffled_targets = targets_equal_priors[shuffled_indices]

# %% [markdown]
# # Split the data into train, validation and test

# %%
sample_count = shuffled_indices.shape[0]

train_sample_count = int(0.8 * sample_count)
vaidation_sample_count = int(0.1 * sample_count)
test_sample_count = sample_count - train_sample_count - vaidation_sample_count
print(train_sample_count, vaidation_sample_count, test_sample_count)
# Out:
# 3579 447 448

# %%
train_inputs = shuffled_inputs[:train_sample_count]
train_targets = shuffled_targets[:train_sample_count]

validation_inputs = shuffled_inputs[train_sample_count:train_sample_count+vaidation_sample_count]
validation_targets = shuffled_targets[train_sample_count:train_sample_count+vaidation_sample_count]

test_inputs = shuffled_inputs[train_sample_count+vaidation_sample_count:]
test_targets = shuffled_targets[train_sample_count+vaidation_sample_count:]

# %%
print(np.sum(train_targets), train_sample_count, np.sum(train_targets) / train_sample_count)
print(np.sum(validation_targets), vaidation_sample_count, np.sum(validation_targets) / vaidation_sample_count)
print(np.sum(test_targets), test_sample_count, np.sum(test_targets) / test_sample_count)
# Out:
# 1790.0 3579 0.5001397038278849
# 235.0 447 0.5257270693512305
# 212.0 448 0.4732142857142857

# %% [markdown]
# # Saving the data in .npz file

# %%
np.savez('Audiobooks_data_train', inputs=train_inputs, targets=train_targets)
np.savez('Audiobooks_data_validation', inputs=validation_inputs, targets=validation_targets)
np.savez('Audiobooks_data_test', inputs=test_inputs, targets=test_targets)

# %% [markdown]
# # Creating methods for batching

# %%
class Audiobooks_Data_Reader():
    
    def __init__(self, dataset, batch_size = None):
    
        # The dataset that loads is one of "train", "validation", "test".
        # e.g. if I call this class with x('train',5), it will load 'Audiobooks_data_train.npz' with a batch size of 5.
        npz = np.load('Audiobooks_data_{0}.npz'.format(dataset))
        self.inputs, self.targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)
        
        # Counts the batch number, given the size you feed it later
        # If the batch size is None, we are either validating or testing, so we want to take the data in a single batch
        if batch_size is None:
            self.batch_size = self.inputs.shape[0]
        else:
            self.batch_size = batch_size
        self.curr_batch = 0
        self.batch_count = self.inputs.shape[0] // self.batch_size
    
    # A method which loads the next batch
    def __next__(self):
        if self.curr_batch >= self.batch_count:
            self.curr_batch = 0
            raise StopIteration()
            
        # You slice the dataset in batches and then the "next" function loads them one after the other
        batch_slice = slice(self.curr_batch * self.batch_size, (self.curr_batch + 1) * self.batch_size)
        inputs_batch = self.inputs[batch_slice]
        targets_batch = self.targets[batch_slice]
        self.curr_batch += 1
        
        # One-hot encode the targets. In this example it's a bit superfluous since we have a 0/1 column 
        # as a target already but we're giving you the code regardless, as it will be useful for any 
        # classification task with more than one target column
        classes_num = 2
        targets_one_hot = np.zeros((targets_batch.shape[0], classes_num))
        targets_one_hot[range(targets_batch.shape[0]), targets_batch] = 1
        
        # The function will return the inputs batch and the one-hot encoded targets
        return inputs_batch, targets_one_hot
    
        
    # A method needed for iterating over the batches, as we will put them in a loop
    # This tells Python that the class we're defining is iterable, i.e. that we can use it like:
    # for input, output in data: 
        # do things
    # An iterator in Python is a class with a method __next__ that defines exactly how to iterate through its objects
    def __iter__(self):
        return self

# %% [markdown]
# # Create the machine learning algorithm

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
#import input_data
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/compat/v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
input_size = 10
output_size = 2
hidden_layer_size = 50

# Reset any variables left in memory from previous runs.
tf.reset_default_graph()

# As in the previous example - declare placeholders where the data will be fed into.
inputs = tf.placeholder(tf.float32, [None, input_size])
targets = tf.placeholder(tf.int32, [None, output_size])


# -----------------------------------     2 Hidden Layers    -------------------------------------------
weights_1 = tf.get_variable("weights_1", [input_size, hidden_layer_size])
biases_1 = tf.get_variable("biases_1", [hidden_layer_size])
outputs_1 = tf.nn.relu(tf.matmul(inputs, weights_1) + biases_1)

weights_2 = tf.get_variable("weights_2", [hidden_layer_size, hidden_layer_size])
biases_2 = tf.get_variable("biases_2", [hidden_layer_size])
outputs_2 = tf.nn.sigmoid(tf.matmul(outputs_1, weights_2) + biases_2)

weights_3 = tf.get_variable("weights_3", [hidden_layer_size, output_size])
biases_3 = tf.get_variable("biases_3", [output_size])
outputs = tf.matmul(outputs_2, weights_3) + biases_3

# ------------------------------------------------------------------------------------------------------


loss = tf.nn.softmax_cross_entropy_with_logits(logits=outputs, labels=targets)
mean_loss = tf.reduce_mean(loss)

# Get a 0 or 1 for every input indicating whether it output the correct answer
out_equals_target = tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(out_equals_target, tf.float32))

# Optimize with Adam
optimize = tf.train.AdamOptimizer(learning_rate=0.0001).minimize(mean_loss)
# Out:
# WARNING:tensorflow:From <ipython-input-19-fad41f576f5b>:29: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %% [markdown]
# # Creating Session

# %%
sess = tf.InteractiveSession()
initializer = tf.global_variables_initializer()      # Initialize the variables. Default initializer is Xavier.
sess.run(initializer)

# %%
batch_size = 100
max_epochs = 1000
prev_validation_loss = 9999999.

# %% [markdown]
# # Loading the data

# %%
train_data = Audiobooks_Data_Reader('train', batch_size)
validation_data = Audiobooks_Data_Reader('validation')

# %%
# Create the loop for epochs 
for epoch_counter in range(max_epochs):
    
    # Set the epoch loss to 0, and make it a float
    curr_epoch_loss = 0.
    
    # Iterate over the training data 
    # Since train_data is an instance of the Audiobooks_Data_Reader class,
    # we can iterate through it by implicitly using the __next__ method we defined above.
    # As a reminder, it batches samples together, one-hot encodes the targets, and returns
    # inputs and targets batch by batch
    for input_batch, target_batch in train_data:
        _, batch_loss = sess.run([optimize, mean_loss], 
            feed_dict={inputs: input_batch, targets: target_batch})
        
        #Record the batch loss into the current epoch loss
        curr_epoch_loss += batch_loss
    
    # Find the mean curr_epoch_loss
    # batch_count is a variable, defined in the Audiobooks_Data_Reader class
    curr_epoch_loss /= train_data.batch_count
    
    # Set validation loss and accuracy for the epoch to zero
    validation_loss = 0.
    validation_accuracy = 0.
    
    # Use the same logic of the code to forward propagate the validation set
    # There will be a single batch, as the class was created in this way
    for input_batch, target_batch in validation_data:
        validation_loss, validation_accuracy = sess.run([mean_loss, accuracy],
            feed_dict={inputs: input_batch, targets: target_batch})
    
    # Print statistics for the current epoch
    print('Epoch '+str(epoch_counter+1)+
          '. Training loss: '+'{0:.3f}'.format(curr_epoch_loss)+
          '. Validation loss: '+'{0:.3f}'.format(validation_loss)+
          '. Validation accuracy: '+'{0:.2f}'.format(validation_accuracy * 100.)+'%')
    
    # Trigger early stopping if validation loss begins increasing.
    if validation_loss > prev_validation_loss:
        print("BREAKING")
        print(validation_loss, prev_validation_loss)
        break
        
    # Store this epoch's validation loss to be used as previous in the next iteration.
    prev_validation_loss = validation_loss
    
print('End of training.')
# Out:
# Epoch 1. Training loss: 1.034. Validation loss: 1.024. Validation accuracy: 47.43%
# Epoch 2. Training loss: 0.942. Validation loss: 0.932. Validation accuracy: 47.43%
# Epoch 3. Training loss: 0.864. Validation loss: 0.856. Validation accuracy: 47.43%
# Epoch 4. Training loss: 0.802. Validation loss: 0.795. Validation accuracy: 47.20%
# Epoch 5. Training loss: 0.754. Validation loss: 0.749. Validation accuracy: 47.43%
# Epoch 6. Training loss: 0.718. Validation loss: 0.715. Validation accuracy: 48.99%
# Epoch 7. Training loss: 0.692. Validation loss: 0.690. Validation accuracy: 51.68%
# Epoch 8. Training loss: 0.674. Validation loss: 0.671. Validation accuracy: 56.82%
# Epoch 9. Training loss: 0.660. Validation loss: 0.657. Validation accuracy: 61.74%
# Epoch 10. Training loss: 0.650. Validation loss: 0.646. Validation accuracy: 66.67%
# Epoch 11. Training loss: 0.641. Validation loss: 0.637. Validation accuracy: 67.56%
# Epoch 12. Training loss: 0.634. Validation loss: 0.629. Validation accuracy: 69.57%
# Epoch 13. Training loss: 0.627. Validation loss: 0.621. Validation accuracy: 69.57%
# Epoch 14. Training loss: 0.620. Validation loss: 0.614. Validation accuracy: 69.80%
# Epoch 15. Training loss: 0.614. Validation loss: 0.607. Validation accuracy: 70.69%
# Epoch 16. Training loss: 0.608. Validation loss: 0.601. Validation accuracy: 71.81%
# Epoch 17. Training loss: 0.602. Validation loss: 0.594. Validation accuracy: 71.81%
# Epoch 18. Training loss: 0.596. Validation loss: 0.588. Validation accuracy: 71.81%
# Epoch 19. Training loss: 0.590. Validation loss: 0.582. Validation accuracy: 72.04%
# Epoch 20. Training loss: 0.584. Validation loss: 0.576. Validation accuracy: 71.81%
# Epoch 21. Training loss: 0.578. Validation loss: 0.570. Validation accuracy: 72.71%
# Epoch 22. Training loss: 0.573. Validation loss: 0.564. Validation accuracy: 73.38%
# Epoch 23. Training loss: 0.567. Validation loss: 0.558. Validation accuracy: 73.38%
# Epoch 24. Training loss: 0.561. Validation loss: 0.553. Validation accuracy: 74.27%
# Epoch 25. Training loss: 0.556. Validation loss: 0.547. Validation accuracy: 75.39%
# Epoch 26. Training loss: 0.551. Validation loss: 0.542. Validation accuracy: 75.39%
# Epoch 27. Training loss: 0.546. Validation loss: 0.536. Validation accuracy: 75.62%
# Epoch 28. Training loss: 0.541. Validation loss: 0.531. Validation accuracy: 76.96%
# Epoch 29. Training loss: 0.536. Validation loss: 0.526. Validation accuracy: 77.18%
# Epoch 30. Training loss: 0.531. Validation loss: 0.522. Validation accuracy: 77.63%
# Epoch 31. Training loss: 0.526. Validation loss: 0.517. Validation accuracy: 78.08%
# Epoch 32. Training loss: 0.522. Validation loss: 0.512. Validation accuracy: 78.08%
# Epoch 33. Training loss: 0.518. Validation loss: 0.508. Validation accuracy: 78.08%
# Epoch 34. Training loss: 0.513. Validation loss: 0.504. Validation accuracy: 77.85%
# Epoch 35. Training loss: 0.509. Validation loss: 0.499. Validation accuracy: 77.85%
# Epoch 36. Training loss: 0.505. Validation loss: 0.495. Validation accuracy: 78.52%
# Epoch 37. Training loss: 0.502. Validation loss: 0.491. Validation accuracy: 78.52%
# Epoch 38. Training loss: 0.498. Validation loss: 0.488. Validation accuracy: 78.97%
# Epoch 39. Training loss: 0.494. Validation loss: 0.484. Validation accuracy: 78.97%
# Epoch 40. Training loss: 0.491. Validation loss: 0.480. Validation accuracy: 79.19%
# Epoch 41. Training loss: 0.487. Validation loss: 0.477. Validation accuracy: 78.75%
# Epoch 42. Training loss: 0.484. Validation loss: 0.474. Validation accuracy: 78.75%
# Epoch 43. Training loss: 0.481. Validation loss: 0.471. Validation accuracy: 78.97%
# Epoch 44. Training loss: 0.478. Validation loss: 0.468. Validation accuracy: 79.42%
# Epoch 45. Training loss: 0.475. Validation loss: 0.465. Validation accuracy: 79.42%
# Epoch 46. Training loss: 0.472. Validation loss: 0.462. Validation accuracy: 79.42%
# Epoch 47. Training loss: 0.470. Validation loss: 0.459. Validation accuracy: 79.64%
# Epoch 48. Training loss: 0.467. Validation loss: 0.456. Validation accuracy: 79.64%
# Epoch 49. Training loss: 0.465. Validation loss: 0.454. Validation accuracy: 79.87%
# Epoch 50. Training loss: 0.462. Validation loss: 0.451. Validation accuracy: 79.87%
# Epoch 51. Training loss: 0.460. Validation loss: 0.449. Validation accuracy: 79.87%
# Epoch 52. Training loss: 0.457. Validation loss: 0.447. Validation accuracy: 79.87%
# Epoch 53. Training loss: 0.455. Validation loss: 0.444. Validation accuracy: 79.87%
# Epoch 54. Training loss: 0.453. Validation loss: 0.442. Validation accuracy: 79.87%
# Epoch 55. Training loss: 0.451. Validation loss: 0.440. Validation accuracy: 79.87%
# Epoch 56. Training loss: 0.449. Validation loss: 0.438. Validation accuracy: 79.87%
# Epoch 57. Training loss: 0.447. Validation loss: 0.436. Validation accuracy: 80.09%
# Epoch 58. Training loss: 0.445. Validation loss: 0.434. Validation accuracy: 80.09%
# Epoch 59. Training loss: 0.443. Validation loss: 0.432. Validation accuracy: 80.09%
# Epoch 60. Training loss: 0.441. Validation loss: 0.431. Validation accuracy: 80.09%
# Epoch 61. Training loss: 0.439. Validation loss: 0.429. Validation accuracy: 79.87%
# Epoch 62. Training loss: 0.438. Validation loss: 0.427. Validation accuracy: 79.64%
# Epoch 63. Training loss: 0.436. Validation loss: 0.426. Validation accuracy: 79.87%
# Epoch 64. Training loss: 0.435. Validation loss: 0.424. Validation accuracy: 79.87%
# Epoch 65. Training loss: 0.433. Validation loss: 0.423. Validation accuracy: 79.87%
# Epoch 66. Training loss: 0.431. Validation loss: 0.421. Validation accuracy: 79.42%
# Epoch 67. Training loss: 0.430. Validation loss: 0.420. Validation accuracy: 79.19%
# Epoch 68. Training loss: 0.428. Validation loss: 0.419. Validation accuracy: 79.19%
# Epoch 69. Training loss: 0.427. Validation loss: 0.417. Validation accuracy: 79.19%
# Epoch 70. Training loss: 0.426. Validation loss: 0.416. Validation accuracy: 79.19%
# Epoch 71. Training loss: 0.424. Validation loss: 0.415. Validation accuracy: 79.64%
# Epoch 72. Training loss: 0.423. Validation loss: 0.414. Validation accuracy: 79.64%
# Epoch 73. Training loss: 0.422. Validation loss: 0.413. Validation accuracy: 79.64%
# Epoch 74. Training loss: 0.420. Validation loss: 0.412. Validation accuracy: 79.64%
# Epoch 75. Training loss: 0.419. Validation loss: 0.411. Validation accuracy: 79.87%
# Epoch 76. Training loss: 0.418. Validation loss: 0.410. Validation accuracy: 80.31%
# Epoch 77. Training loss: 0.417. Validation loss: 0.409. Validation accuracy: 80.54%
# Epoch 78. Training loss: 0.416. Validation loss: 0.408. Validation accuracy: 80.76%
# Epoch 79. Training loss: 0.415. Validation loss: 0.407. Validation accuracy: 80.98%
# Epoch 80. Training loss: 0.414. Validation loss: 0.406. Validation accuracy: 80.98%
# Epoch 81. Training loss: 0.413. Validation loss: 0.405. Validation accuracy: 80.98%
# Epoch 82. Training loss: 0.412. Validation loss: 0.404. Validation accuracy: 80.98%
# Epoch 83. Training loss: 0.411. Validation loss: 0.403. Validation accuracy: 80.98%
# Epoch 84. Training loss: 0.410. Validation loss: 0.402. Validation accuracy: 80.98%
# Epoch 85. Training loss: 0.409. Validation loss: 0.402. Validation accuracy: 81.21%
# Epoch 86. Training loss: 0.408. Validation loss: 0.401. Validation accuracy: 80.98%
# Epoch 87. Training loss: 0.407. Validation loss: 0.400. Validation accuracy: 80.98%
# Epoch 88. Training loss: 0.406. Validation loss: 0.399. Validation accuracy: 81.21%
# Epoch 89. Training loss: 0.405. Validation loss: 0.399. Validation accuracy: 80.98%
# Epoch 90. Training loss: 0.404. Validation loss: 0.398. Validation accuracy: 80.98%
# Epoch 91. Training loss: 0.403. Validation loss: 0.397. Validation accuracy: 80.98%
# Epoch 92. Training loss: 0.403. Validation loss: 0.397. Validation accuracy: 80.98%
# Epoch 93. Training loss: 0.402. Validation loss: 0.396. Validation accuracy: 80.98%
# Epoch 94. Training loss: 0.401. Validation loss: 0.396. Validation accuracy: 80.98%
# Epoch 95. Training loss: 0.400. Validation loss: 0.395. Validation accuracy: 80.98%
# Epoch 96. Training loss: 0.400. Validation loss: 0.394. Validation accuracy: 80.76%
# Epoch 97. Training loss: 0.399. Validation loss: 0.394. Validation accuracy: 80.76%
# Epoch 98. Training loss: 0.398. Validation loss: 0.393. Validation accuracy: 80.76%
# Epoch 99. Training loss: 0.397. Validation loss: 0.393. Validation accuracy: 80.76%
# Epoch 100. Training loss: 0.397. Validation loss: 0.392. Validation accuracy: 80.76%
# Epoch 101. Training loss: 0.396. Validation loss: 0.392. Validation accuracy: 80.76%
# Epoch 102. Training loss: 0.395. Validation loss: 0.391. Validation accuracy: 80.76%
# Epoch 103. Training loss: 0.395. Validation loss: 0.391. Validation accuracy: 80.76%
# Epoch 104. Training loss: 0.394. Validation loss: 0.390. Validation accuracy: 80.76%
# Epoch 105. Training loss: 0.394. Validation loss: 0.390. Validation accuracy: 80.54%
# Epoch 106. Training loss: 0.393. Validation loss: 0.389. Validation accuracy: 80.54%
# Epoch 107. Training loss: 0.392. Validation loss: 0.389. Validation accuracy: 80.31%
# Epoch 108. Training loss: 0.392. Validation loss: 0.388. Validation accuracy: 80.31%
# Epoch 109. Training loss: 0.391. Validation loss: 0.388. Validation accuracy: 80.31%
# Epoch 110. Training loss: 0.391. Validation loss: 0.387. Validation accuracy: 80.31%
# Epoch 111. Training loss: 0.390. Validation loss: 0.387. Validation accuracy: 80.31%
# Epoch 112. Training loss: 0.389. Validation loss: 0.386. Validation accuracy: 80.31%
# Epoch 113. Training loss: 0.389. Validation loss: 0.386. Validation accuracy: 80.31%
# Epoch 114. Training loss: 0.388. Validation loss: 0.386. Validation accuracy: 80.31%
# Epoch 115. Training loss: 0.388. Validation loss: 0.385. Validation accuracy: 80.31%
# Epoch 116. Training loss: 0.387. Validation loss: 0.385. Validation accuracy: 80.09%
# Epoch 117. Training loss: 0.387. Validation loss: 0.384. Validation accuracy: 80.09%
# Epoch 118. Training loss: 0.386. Validation loss: 0.384. Validation accuracy: 80.09%
# Epoch 119. Training loss: 0.386. Validation loss: 0.384. Validation accuracy: 80.09%
# Epoch 120. Training loss: 0.385. Validation loss: 0.383. Validation accuracy: 80.09%
# Epoch 121. Training loss: 0.385. Validation loss: 0.383. Validation accuracy: 80.09%
# Epoch 122. Training loss: 0.384. Validation loss: 0.383. Validation accuracy: 80.09%
# Epoch 123. Training loss: 0.384. Validation loss: 0.382. Validation accuracy: 80.09%
# Epoch 124. Training loss: 0.383. Validation loss: 0.382. Validation accuracy: 80.54%
# Epoch 125. Training loss: 0.383. Validation loss: 0.382. Validation accuracy: 80.76%
# Epoch 126. Training loss: 0.383. Validation loss: 0.381. Validation accuracy: 80.76%
# Epoch 127. Training loss: 0.382. Validation loss: 0.381. Validation accuracy: 80.98%
# Epoch 128. Training loss: 0.382. Validation loss: 0.381. Validation accuracy: 80.98%
# Epoch 129. Training loss: 0.381. Validation loss: 0.380. Validation accuracy: 80.76%
# Epoch 130. Training loss: 0.381. Validation loss: 0.380. Validation accuracy: 80.76%
# Epoch 131. Training loss: 0.380. Validation loss: 0.380. Validation accuracy: 80.98%
# Epoch 132. Training loss: 0.380. Validation loss: 0.379. Validation accuracy: 80.98%
# Epoch 133. Training loss: 0.380. Validation loss: 0.379. Validation accuracy: 81.21%
# Epoch 134. Training loss: 0.379. Validation loss: 0.379. Validation accuracy: 81.21%
# Epoch 135. Training loss: 0.379. Validation loss: 0.379. Validation accuracy: 81.21%
# Epoch 136. Training loss: 0.379. Validation loss: 0.378. Validation accuracy: 81.21%
# Epoch 137. Training loss: 0.378. Validation loss: 0.378. Validation accuracy: 81.21%
# Epoch 138. Training loss: 0.378. Validation loss: 0.378. Validation accuracy: 81.21%
# Epoch 139. Training loss: 0.377. Validation loss: 0.377. Validation accuracy: 81.21%
# Epoch 140. Training loss: 0.377. Validation loss: 0.377. Validation accuracy: 81.21%
# Epoch 141. Training loss: 0.377. Validation loss: 0.377. Validation accuracy: 81.21%
# Epoch 142. Training loss: 0.376. Validation loss: 0.377. Validation accuracy: 81.21%
# Epoch 143. Training loss: 0.376. Validation loss: 0.376. Validation accuracy: 81.21%
# Epoch 144. Training loss: 0.376. Validation loss: 0.376. Validation accuracy: 81.21%
# Epoch 145. Training loss: 0.375. Validation loss: 0.376. Validation accuracy: 81.21%
# Epoch 146. Training loss: 0.375. Validation loss: 0.376. Validation accuracy: 81.21%
# Epoch 147. Training loss: 0.375. Validation loss: 0.375. Validation accuracy: 81.21%
# Epoch 148. Training loss: 0.374. Validation loss: 0.375. Validation accuracy: 81.43%
# Epoch 149. Training loss: 0.374. Validation loss: 0.375. Validation accuracy: 81.43%
# Epoch 150. Training loss: 0.374. Validation loss: 0.375. Validation accuracy: 81.43%
# Epoch 151. Training loss: 0.374. Validation loss: 0.374. Validation accuracy: 81.43%
# Epoch 152. Training loss: 0.373. Validation loss: 0.374. Validation accuracy: 81.43%
# Epoch 153. Training loss: 0.373. Validation loss: 0.374. Validation accuracy: 81.43%
# Epoch 154. Training loss: 0.373. Validation loss: 0.374. Validation accuracy: 81.43%
# Epoch 155. Training loss: 0.372. Validation loss: 0.374. Validation accuracy: 81.43%
# Epoch 156. Training loss: 0.372. Validation loss: 0.373. Validation accuracy: 81.21%
# Epoch 157. Training loss: 0.372. Validation loss: 0.373. Validation accuracy: 81.21%
# Epoch 158. Training loss: 0.372. Validation loss: 0.373. Validation accuracy: 81.21%
# Epoch 159. Training loss: 0.371. Validation loss: 0.373. Validation accuracy: 81.21%
# Epoch 160. Training loss: 0.371. Validation loss: 0.373. Validation accuracy: 81.21%
# Epoch 161. Training loss: 0.371. Validation loss: 0.372. Validation accuracy: 81.21%
# Epoch 162. Training loss: 0.370. Validation loss: 0.372. Validation accuracy: 81.21%
# Epoch 163. Training loss: 0.370. Validation loss: 0.372. Validation accuracy: 80.98%
# Epoch 164. Training loss: 0.370. Validation loss: 0.372. Validation accuracy: 80.98%
# Epoch 165. Training loss: 0.370. Validation loss: 0.372. Validation accuracy: 81.21%
# Epoch 166. Training loss: 0.369. Validation loss: 0.371. Validation accuracy: 81.21%
# Epoch 167. Training loss: 0.369. Validation loss: 0.371. Validation accuracy: 81.21%
# Epoch 168. Training loss: 0.369. Validation loss: 0.371. Validation accuracy: 81.21%
# Epoch 169. Training loss: 0.369. Validation loss: 0.371. Validation accuracy: 81.21%
# Epoch 170. Training loss: 0.368. Validation loss: 0.371. Validation accuracy: 80.98%
# Epoch 171. Training loss: 0.368. Validation loss: 0.371. Validation accuracy: 80.76%
# Epoch 172. Training loss: 0.368. Validation loss: 0.370. Validation accuracy: 80.76%
# Epoch 173. Training loss: 0.368. Validation loss: 0.370. Validation accuracy: 80.76%
# Epoch 174. Training loss: 0.368. Validation loss: 0.370. Validation accuracy: 80.76%
# Epoch 175. Training loss: 0.367. Validation loss: 0.370. Validation accuracy: 80.76%
# Epoch 176. Training loss: 0.367. Validation loss: 0.370. Validation accuracy: 80.76%
# Epoch 177. Training loss: 0.367. Validation loss: 0.369. Validation accuracy: 80.76%
# Epoch 178. Training loss: 0.367. Validation loss: 0.369. Validation accuracy: 80.98%
# Epoch 179. Training loss: 0.366. Validation loss: 0.369. Validation accuracy: 80.98%
# Epoch 180. Training loss: 0.366. Validation loss: 0.369. Validation accuracy: 80.98%
# Epoch 181. Training loss: 0.366. Validation loss: 0.369. Validation accuracy: 80.98%
# Epoch 182. Training loss: 0.366. Validation loss: 0.369. Validation accuracy: 80.98%
# Epoch 183. Training loss: 0.366. Validation loss: 0.369. Validation accuracy: 80.98%
# Epoch 184. Training loss: 0.365. Validation loss: 0.368. Validation accuracy: 80.98%
# Epoch 185. Training loss: 0.365. Validation loss: 0.368. Validation accuracy: 80.98%
# Epoch 186. Training loss: 0.365. Validation loss: 0.368. Validation accuracy: 80.98%
# Epoch 187. Training loss: 0.365. Validation loss: 0.368. Validation accuracy: 80.98%
# Epoch 188. Training loss: 0.365. Validation loss: 0.368. Validation accuracy: 80.98%
# Epoch 189. Training loss: 0.365. Validation loss: 0.368. Validation accuracy: 80.98%
# Epoch 190. Training loss: 0.364. Validation loss: 0.368. Validation accuracy: 80.98%
# Epoch 191. Training loss: 0.364. Validation loss: 0.367. Validation accuracy: 80.98%
# Epoch 192. Training loss: 0.364. Validation loss: 0.367. Validation accuracy: 80.98%
# Epoch 193. Training loss: 0.364. Validation loss: 0.367. Validation accuracy: 80.98%
# Epoch 194. Training loss: 0.364. Validation loss: 0.367. Validation accuracy: 80.98%
# Epoch 195. Training loss: 0.363. Validation loss: 0.367. Validation accuracy: 80.98%
# Epoch 196. Training loss: 0.363. Validation loss: 0.367. Validation accuracy: 80.98%
# Epoch 197. Training loss: 0.363. Validation loss: 0.367. Validation accuracy: 80.98%
# Epoch 198. Training loss: 0.363. Validation loss: 0.366. Validation accuracy: 80.98%
# Epoch 199. Training loss: 0.363. Validation loss: 0.366. Validation accuracy: 80.98%
# Epoch 200. Training loss: 0.363. Validation loss: 0.366. Validation accuracy: 80.98%
# Epoch 201. Training loss: 0.362. Validation loss: 0.366. Validation accuracy: 80.98%
# Epoch 202. Training loss: 0.362. Validation loss: 0.366. Validation accuracy: 80.98%
# Epoch 203. Training loss: 0.362. Validation loss: 0.366. Validation accuracy: 80.98%
# Epoch 204. Training loss: 0.362. Validation loss: 0.366. Validation accuracy: 80.98%
# Epoch 205. Training loss: 0.362. Validation loss: 0.366. Validation accuracy: 80.98%
# Epoch 206. Training loss: 0.362. Validation loss: 0.366. Validation accuracy: 80.98%
# Epoch 207. Training loss: 0.361. Validation loss: 0.365. Validation accuracy: 80.98%
# Epoch 208. Training loss: 0.361. Validation loss: 0.365. Validation accuracy: 80.98%
# Epoch 209. Training loss: 0.361. Validation loss: 0.365. Validation accuracy: 80.98%
# Epoch 210. Training loss: 0.361. Validation loss: 0.365. Validation accuracy: 80.98%
# Epoch 211. Training loss: 0.361. Validation loss: 0.365. Validation accuracy: 80.98%
# Epoch 212. Training loss: 0.361. Validation loss: 0.365. Validation accuracy: 80.98%
# Epoch 213. Training loss: 0.360. Validation loss: 0.365. Validation accuracy: 80.98%
# Epoch 214. Training loss: 0.360. Validation loss: 0.365. Validation accuracy: 80.98%
# Epoch 215. Training loss: 0.360. Validation loss: 0.364. Validation accuracy: 80.98%
# Epoch 216. Training loss: 0.360. Validation loss: 0.364. Validation accuracy: 80.98%
# Epoch 217. Training loss: 0.360. Validation loss: 0.364. Validation accuracy: 81.21%
# Epoch 218. Training loss: 0.360. Validation loss: 0.364. Validation accuracy: 80.98%
# Epoch 219. Training loss: 0.360. Validation loss: 0.364. Validation accuracy: 80.98%
# Epoch 220. Training loss: 0.359. Validation loss: 0.364. Validation accuracy: 80.98%
# Epoch 221. Training loss: 0.359. Validation loss: 0.364. Validation accuracy: 80.98%
# Epoch 222. Training loss: 0.359. Validation loss: 0.364. Validation accuracy: 80.98%
# Epoch 223. Training loss: 0.359. Validation loss: 0.364. Validation accuracy: 80.98%
# Epoch 224. Training loss: 0.359. Validation loss: 0.364. Validation accuracy: 80.98%
# Epoch 225. Training loss: 0.359. Validation loss: 0.363. Validation accuracy: 80.98%
# Epoch 226. Training loss: 0.359. Validation loss: 0.363. Validation accuracy: 80.98%
# Epoch 227. Training loss: 0.359. Validation loss: 0.363. Validation accuracy: 80.98%
# Epoch 228. Training loss: 0.358. Validation loss: 0.363. Validation accuracy: 80.98%
# Epoch 229. Training loss: 0.358. Validation loss: 0.363. Validation accuracy: 80.98%
# Epoch 230. Training loss: 0.358. Validation loss: 0.363. Validation accuracy: 80.98%
# Epoch 231. Training loss: 0.358. Validation loss: 0.363. Validation accuracy: 80.98%
# Epoch 232. Training loss: 0.358. Validation loss: 0.363. Validation accuracy: 80.98%
# Epoch 233. Training loss: 0.358. Validation loss: 0.363. Validation accuracy: 80.98%
# Epoch 234. Training loss: 0.358. Validation loss: 0.363. Validation accuracy: 80.98%
# Epoch 235. Training loss: 0.358. Validation loss: 0.363. Validation accuracy: 80.98%
# Epoch 236. Training loss: 0.357. Validation loss: 0.362. Validation accuracy: 80.98%
# Epoch 237. Training loss: 0.357. Validation loss: 0.362. Validation accuracy: 80.98%
# Epoch 238. Training loss: 0.357. Validation loss: 0.362. Validation accuracy: 80.98%
# Epoch 239. Training loss: 0.357. Validation loss: 0.362. Validation accuracy: 80.98%
# Epoch 240. Training loss: 0.357. Validation loss: 0.362. Validation accuracy: 80.98%
# Epoch 241. Training loss: 0.357. Validation loss: 0.362. Validation accuracy: 80.98%
# Epoch 242. Training loss: 0.357. Validation loss: 0.362. Validation accuracy: 80.98%
# Epoch 243. Training loss: 0.357. Validation loss: 0.362. Validation accuracy: 80.98%
# Epoch 244. Training loss: 0.356. Validation loss: 0.362. Validation accuracy: 80.98%
# Epoch 245. Training loss: 0.356. Validation loss: 0.362. Validation accuracy: 80.98%
# Epoch 246. Training loss: 0.356. Validation loss: 0.362. Validation accuracy: 80.98%
# Epoch 247. Training loss: 0.356. Validation loss: 0.361. Validation accuracy: 80.98%
# Epoch 248. Training loss: 0.356. Validation loss: 0.361. Validation accuracy: 80.98%
# Epoch 249. Training loss: 0.356. Validation loss: 0.361. Validation accuracy: 80.98%
# Epoch 250. Training loss: 0.356. Validation loss: 0.361. Validation accuracy: 80.98%
# Epoch 251. Training loss: 0.356. Validation loss: 0.361. Validation accuracy: 80.98%
# Epoch 252. Training loss: 0.355. Validation loss: 0.361. Validation accuracy: 80.98%
# Epoch 253. Training loss: 0.355. Validation loss: 0.361. Validation accuracy: 80.98%
# Epoch 254. Training loss: 0.355. Validation loss: 0.361. Validation accuracy: 80.98%
# Epoch 255. Training loss: 0.355. Validation loss: 0.361. Validation accuracy: 80.98%
# Epoch 256. Training loss: 0.355. Validation loss: 0.361. Validation accuracy: 80.98%
# Epoch 257. Training loss: 0.355. Validation loss: 0.361. Validation accuracy: 80.98%
# Epoch 258. Training loss: 0.355. Validation loss: 0.361. Validation accuracy: 80.98%
# Epoch 259. Training loss: 0.355. Validation loss: 0.360. Validation accuracy: 80.98%
# Epoch 260. Training loss: 0.355. Validation loss: 0.360. Validation accuracy: 80.98%
# Epoch 261. Training loss: 0.355. Validation loss: 0.360. Validation accuracy: 80.98%
# Epoch 262. Training loss: 0.354. Validation loss: 0.360. Validation accuracy: 80.98%
# Epoch 263. Training loss: 0.354. Validation loss: 0.360. Validation accuracy: 80.98%
# Epoch 264. Training loss: 0.354. Validation loss: 0.360. Validation accuracy: 80.98%
# Epoch 265. Training loss: 0.354. Validation loss: 0.360. Validation accuracy: 80.98%
# Epoch 266. Training loss: 0.354. Validation loss: 0.360. Validation accuracy: 81.21%
# Epoch 267. Training loss: 0.354. Validation loss: 0.360. Validation accuracy: 80.98%
# Epoch 268. Training loss: 0.354. Validation loss: 0.360. Validation accuracy: 80.98%
# Epoch 269. Training loss: 0.354. Validation loss: 0.360. Validation accuracy: 80.98%
# Epoch 270. Training loss: 0.354. Validation loss: 0.360. Validation accuracy: 80.98%
# Epoch 271. Training loss: 0.354. Validation loss: 0.360. Validation accuracy: 80.98%
# Epoch 272. Training loss: 0.353. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 273. Training loss: 0.353. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 274. Training loss: 0.353. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 275. Training loss: 0.353. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 276. Training loss: 0.353. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 277. Training loss: 0.353. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 278. Training loss: 0.353. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 279. Training loss: 0.353. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 280. Training loss: 0.353. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 281. Training loss: 0.353. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 282. Training loss: 0.353. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 283. Training loss: 0.352. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 284. Training loss: 0.352. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 285. Training loss: 0.352. Validation loss: 0.359. Validation accuracy: 80.98%
# Epoch 286. Training loss: 0.352. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 287. Training loss: 0.352. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 288. Training loss: 0.352. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 289. Training loss: 0.352. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 290. Training loss: 0.352. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 291. Training loss: 0.352. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 292. Training loss: 0.352. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 293. Training loss: 0.352. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 294. Training loss: 0.352. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 295. Training loss: 0.351. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 296. Training loss: 0.351. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 297. Training loss: 0.351. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 298. Training loss: 0.351. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 299. Training loss: 0.351. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 300. Training loss: 0.351. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 301. Training loss: 0.351. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 302. Training loss: 0.351. Validation loss: 0.357. Validation accuracy: 80.98%
# Epoch 303. Training loss: 0.351. Validation loss: 0.357. Validation accuracy: 80.98%
# Epoch 304. Training loss: 0.351. Validation loss: 0.357. Validation accuracy: 80.98%
# Epoch 305. Training loss: 0.351. Validation loss: 0.357. Validation accuracy: 80.98%
# Epoch 306. Training loss: 0.351. Validation loss: 0.357. Validation accuracy: 80.98%
# Epoch 307. Training loss: 0.351. Validation loss: 0.357. Validation accuracy: 80.98%
# Epoch 308. Training loss: 0.350. Validation loss: 0.357. Validation accuracy: 81.21%
# Epoch 309. Training loss: 0.350. Validation loss: 0.357. Validation accuracy: 81.43%
# Epoch 310. Training loss: 0.350. Validation loss: 0.357. Validation accuracy: 81.43%
# Epoch 311. Training loss: 0.350. Validation loss: 0.357. Validation accuracy: 81.43%
# Epoch 312. Training loss: 0.350. Validation loss: 0.357. Validation accuracy: 81.66%
# Epoch 313. Training loss: 0.350. Validation loss: 0.357. Validation accuracy: 81.66%
# Epoch 314. Training loss: 0.350. Validation loss: 0.357. Validation accuracy: 81.66%
# Epoch 315. Training loss: 0.350. Validation loss: 0.357. Validation accuracy: 81.66%
# Epoch 316. Training loss: 0.350. Validation loss: 0.357. Validation accuracy: 81.66%
# Epoch 317. Training loss: 0.350. Validation loss: 0.357. Validation accuracy: 81.66%
# Epoch 318. Training loss: 0.350. Validation loss: 0.357. Validation accuracy: 81.66%
# Epoch 319. Training loss: 0.350. Validation loss: 0.356. Validation accuracy: 81.66%
# Epoch 320. Training loss: 0.350. Validation loss: 0.356. Validation accuracy: 81.66%
# Epoch 321. Training loss: 0.350. Validation loss: 0.356. Validation accuracy: 81.66%
# Epoch 322. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.66%
# Epoch 323. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 324. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 325. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 326. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 327. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 328. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 329. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 330. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 331. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 332. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 333. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 334. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 335. Training loss: 0.349. Validation loss: 0.356. Validation accuracy: 81.88%
# Epoch 336. Training loss: 0.349. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 337. Training loss: 0.349. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 338. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 339. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 340. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 341. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 342. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 343. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 344. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 345. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 346. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 347. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 348. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 349. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 350. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 351. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.66%
# Epoch 352. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.66%
# Epoch 353. Training loss: 0.348. Validation loss: 0.355. Validation accuracy: 81.66%
# Epoch 354. Training loss: 0.347. Validation loss: 0.355. Validation accuracy: 81.66%
# Epoch 355. Training loss: 0.347. Validation loss: 0.355. Validation accuracy: 81.66%
# Epoch 356. Training loss: 0.347. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 357. Training loss: 0.347. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 358. Training loss: 0.347. Validation loss: 0.355. Validation accuracy: 81.88%
# Epoch 359. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.88%
# Epoch 360. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.88%
# Epoch 361. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 362. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 363. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 364. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 365. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 366. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 367. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 368. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 369. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 370. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 371. Training loss: 0.347. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 372. Training loss: 0.346. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 373. Training loss: 0.346. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 374. Training loss: 0.346. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 375. Training loss: 0.346. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 376. Training loss: 0.346. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 377. Training loss: 0.346. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 378. Training loss: 0.346. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 379. Training loss: 0.346. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 380. Training loss: 0.346. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 381. Training loss: 0.346. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 382. Training loss: 0.346. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 383. Training loss: 0.346. Validation loss: 0.354. Validation accuracy: 81.66%
# Epoch 384. Training loss: 0.346. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 385. Training loss: 0.346. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 386. Training loss: 0.346. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 387. Training loss: 0.346. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 388. Training loss: 0.346. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 389. Training loss: 0.346. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 390. Training loss: 0.346. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 391. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 392. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 393. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 394. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 395. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 396. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 397. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 398. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 399. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 400. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 401. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 402. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 403. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 404. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 405. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 406. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 407. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 408. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.43%
# Epoch 409. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.43%
# Epoch 410. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.43%
# Epoch 411. Training loss: 0.345. Validation loss: 0.353. Validation accuracy: 81.43%
# Epoch 412. Training loss: 0.344. Validation loss: 0.353. Validation accuracy: 81.43%
# Epoch 413. Training loss: 0.344. Validation loss: 0.353. Validation accuracy: 81.43%
# Epoch 414. Training loss: 0.344. Validation loss: 0.353. Validation accuracy: 81.43%
# Epoch 415. Training loss: 0.344. Validation loss: 0.353. Validation accuracy: 81.66%
# Epoch 416. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 417. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 418. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 419. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 420. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 421. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 422. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 423. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 424. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 425. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 426. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 427. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 428. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 429. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 430. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 431. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 432. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 433. Training loss: 0.344. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 434. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 435. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 436. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 437. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 438. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 439. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 440. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 441. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 442. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 443. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 444. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 445. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 446. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# Epoch 447. Training loss: 0.343. Validation loss: 0.352. Validation accuracy: 81.66%
# BREAKING
# 0.35190296 0.35190186
# End of training.

# %% [markdown]
# # Testing the model

# %%
test_data = Audiobooks_Data_Reader('test')

# %%
for input_batch, target_batch in validation_data:
    test_accuracy = sess.run([accuracy],feed_dict={inputs: input_batch, targets: target_batch})
    
test_accuracy_percent = test_accuracy[0] * 100
print('Test Accuracy: '+'{0:.2f}'.format(test_accuracy_percent) + '%')
# Out:
# Test Accuracy: 81.66%

# %% [markdown]
# # Model II

# %%
npz = np.load('Audiobooks_data_train.npz')
train_inputs = npz['inputs'].astype(np.float)
train_targets = npz['targets'].astype(np.int)

npz = np.load('Audiobooks_data_test.npz')
test_inputs = npz['inputs'].astype(np.float)
test_targets = npz['targets'].astype(np.int)

# %%
input_size = 10
output_size = 2
hidden_layer_size = 50

model = tf.keras.Sequential([
    
    
    # tf.keras.layers.Dense is basically implementing: output = activation(dot(input, weight) + bias)
    # it takes several arguments, but the most important ones for us are the hidden_layer_size and the activation function
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 1st hidden layer
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 2nd hidden layer
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 3rd hidden layer
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 4th hidden layer
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 5th hidden layer
    
    
    # the final layer is no different, we just make sure to activate it with softmax
    tf.keras.layers.Dense(output_size, activation= 'softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
NUM_EPOCHS = 10
batch_size = 100
early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)


# note that this time the train, validation and test data are not iterable
model.fit(train_inputs, # train inputs
          train_targets, # train targets
          batch_size=batch_size, # batch size
          epochs=NUM_EPOCHS, # epochs that we will train for (assuming early stopping doesn't kick in)
          # callbacks are functions called by a task when a task is completed
          # task here is to check if val_loss is increasing
          callbacks=[early_stopping], # early stopping
          validation_data=(validation_inputs, validation_targets), # validation data
          #validation_steps=10,
          verbose = 2 # making sure we get enough information about the training process
          )
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Train on 3579 samples, validate on 447 samples
# Epoch 1/10
# 3579/3579 - 0s - loss: 0.5707 - acc: 0.7220 - val_loss: 0.4871 - val_acc: 0.7562
# Epoch 2/10
# 3579/3579 - 0s - loss: 0.4332 - acc: 0.7695 - val_loss: 0.4152 - val_acc: 0.7987
# Epoch 3/10
# 3579/3579 - 0s - loss: 0.4043 - acc: 0.7930 - val_loss: 0.4181 - val_acc: 0.7897
# Epoch 4/10
# 3579/3579 - 0s - loss: 0.3888 - acc: 0.7985 - val_loss: 0.3816 - val_acc: 0.7942
# Epoch 5/10
# 3579/3579 - 0s - loss: 0.3796 - acc: 0.7966 - val_loss: 0.3759 - val_acc: 0.8009
# Epoch 6/10
# 3579/3579 - 0s - loss: 0.3784 - acc: 0.7963 - val_loss: 0.3839 - val_acc: 0.7830
# Epoch 7/10
# 3579/3579 - 0s - loss: 0.3682 - acc: 0.8053 - val_loss: 0.3871 - val_acc: 0.7897

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 448/448 [==============================] - 0s 66us/sample - loss: 0.3885 - acc: 0.7991

# %%
print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# Test loss: 0.39. Test accuracy: 79.91%

# %%
prediction = model.predict(test_inputs)

# %%
for i in range(len(prediction)):
    print("Predcited", np.argmax(prediction[i]), "Expected", test_targets[i])
# Out:
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 1 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 1 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 0 Expected 1
# Predcited 0 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
# Predcited 0 Expected 0
# Predcited 1 Expected 1
# Predcited 1 Expected 1
